# %%
import pandas as pd
import numpy as np
df = pd.read_csv('greenspace.csv')
df = df.drop(labels = range(0, 242), axis = 0)
df = df.drop(labels = range(312, 315), axis = 0)
df = df.drop(columns = df.columns[1])
df
# Out:
#     Table: Green area per capita  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 242                  Philadelphia    1516.57    1516.57    1516.56    1516.56
# 243                      Columbus     3186.4     3186.4    3186.39    3186.39
# 244                        Denver      12.66      12.68      12.67      12.66
# 245                      Portland     964.25     964.25     964.25     964.25
# 246                     Baltimore    1939.66    1939.66    1939.65    1939.65
# ..                            ...        ...        ...        ...        ...
# 307                    Des Moines    3023.47    3023.47    3023.47    3023.47
# 308                         Omaha     638.82     638.83     638.83     638.83
# 309                         Akron     696.78     696.78     696.78     696.78
# 310                Salt Lake City     630.24     630.24     630.24     630.24
# 311                    Pittsburgh     754.31     754.31     754.31     754.31
#
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
